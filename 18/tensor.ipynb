# %%
import torch

# %%
#tensor 1D com 1 linha e 2 colunas

sample = torch.tensor([10,11])
sample.shape
# Out:
# torch.Size([2])

# %%
#tensor 2D com 2 linhas e 2 colunas

x = torch.tensor([[10,11],[1,2]])
x.shape
# Out:
# torch.Size([2, 2])

# %%
#tensor 2D com 2 linhas e 1 coluna

y = torch.tensor([[10],[11]])
y.shape
# Out:
# torch.Size([2, 1])

# %%
import plotly.graph_objs as go 
import plotly.offline as pyo 

#tensor 3D
a = torch.tensor([[[1,2],[3,4]],[[5,6],[7,8]]])

x_vals = []
y_vals = []
z_vals = []

for i in range(a.shape[0]):
    for j in range(a.shape[1]):
        for k in range(a.shape[2]):
            x_vals.append(i)
            y_vals.append(j)
            z_vals.append(k)

#criando um gráfico 3D para plotar o tensor
trace = go.Scatter3d(x=x_vals, y=y_vals, z=z_vals, mode='markers',
                     marker=dict(
                         size=5,
                         color=a.flatten(),
                         colorscale='Viridis',
                         opacity=0.8
                     ))

layout = go.Layout(
    margin=dict(l=0, r=0, b=0, t=0),
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3')
    )
)

fig = go.Figure(data=[trace], layout=layout)
pyo.plot(fig, filename='tensor.html')
# Out:
# 'tensor.html'
