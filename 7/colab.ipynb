# %% [markdown]
# # Google Colab
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Duis ut rutrum libero. Phasellus euismod efficitur dictum. Suspendisse lacinia ante sit amet tellus volutpat, sed eleifend metus facilisis.

# %%
print("Queria um rx7")
# Out:
# Queria um rx7

# %%
import matplotlib.pyplot as plt

# %%
data = [0, 3, 5, 12, 56, 234]
plt.plot(data)
plt.show()
