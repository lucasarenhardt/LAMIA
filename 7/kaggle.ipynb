# %% [markdown]
# # Kaggle Notebook
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Phasellus id molestie est. Vivamus vehicula euismod suscipit. Suspendisse potenti. Nam tincidunt varius tincidunt.

# %%
print("Queria um mustang")
# Out:
# Queria um mustang

# %%
import pandas as pd

# %%
df = pd.read_csv('../input/world-population-by-country-2024/World Population by country 2024.csv')
paises_selecionados = ["India", "Brazil", "China", "United States"]
df_selecionado = df.loc[df['Country'].isin(paises_selecionados)]
df_selecionado
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 6         Brazil        217637297        216422446       8.4M            26.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# 2       0.0053   0.0427           3
# 6       0.0056   0.0272           7

# %%
df_selecionado.plot(x='Country', y='Population 2024', kind='bar', title='Population')
# Out:
# <Axes: title={'center': 'Population'}, xlabel='Country'>
