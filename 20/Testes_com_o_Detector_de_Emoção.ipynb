# %% [markdown]
# # Testando o modelo do Detector de Emoções

# %% [markdown]
# ## Etapa 1 - Importando as bibliotecas

# %%
#importando as bibliotecas

import cv2
import numpy as np
import pandas as pd
from google.colab.patches import cv2_imshow
import zipfile

# %%
#escolhendo a versão do tensorflow

# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
tensorflow.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ## Etapa 2 - Conectando com o Drive e acessando os arquivos

# %%
#conectando ao google drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#extraindo o material do arquivo .zip

path = "/content/gdrive/My Drive/Material.zip"
zip_object = zipfile.ZipFile(file = path, mode = "r")
zip_object.extractall('./')
zip_object.close
# Out:
# <bound method ZipFile.close of <zipfile.ZipFile filename='/content/gdrive/My Drive/Material.zip' mode='r'>>

# %%
#mostrando uma imagem

imagem = cv2.imread('Material/testes/teste_gabriel.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F324BECDEB8>

# %%
imagem.shape
# Out:
# (300, 400, 3)

# %% [markdown]
# ## Testando o Detector

# %% [markdown]
# ### Carregamento dos modelos

# %%
#carregando os modelos prontos

cascade_faces = "Material/haarcascade_frontalface_default.xml"
caminho_modelo = "Material/modelo_01_expressoes.h5"

#criando os objetos para fazer as classificações de faces e emoções
face_detection = cv2.CascadeClassifier(cascade_faces)
classificador_emocoes = load_model(caminho_modelo, compile = False)

#listando as emoções
expressoes = ["Raiva", "Nojo", "Medo", "Feliz", "Triste", "Surpreso", "Neutro"]

# %% [markdown]
# ### Detecção de faces

# %%
#criando uma copia da imagem
original = imagem.copy()
#aplicando o detector de faces
faces = face_detection.detectMultiScale(original, scaleFactor = 1.1,
                                        minNeighbors = 3, minSize = (20,20))

# %%
faces
# Out:
# array([[162,  40, 128, 128]], dtype=int32)

# %%
len(faces)
# Out:
# 1

# %%
faces.shape
# Out:
# (1, 4)

# %% [markdown]
# ### Extração do ROI (region of interest)

# %%
#transformando a imagem para a escala de cinza

cinza = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
cv2_imshow(cinza)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7F324BEE9A90>

# %%
#agora só tem um canal de cor

cinza.shape
# Out:
# (300, 400)

# %%
#cortando a região de interesse

roi = cinza[40:40 + 128, 162:162 + 128]

# %%
cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=L size=128x128 at 0x7F3243EE7390>

# %%
roi.shape
# Out:
# (128, 128)

# %%
roi
# Out:
# array([[ 39,  37,  28, ...,  25,  29,  34],
#        [ 34,  32,  25, ...,  24,  24,  29],
#        [ 31,  33,  30, ...,  23,  22,  26],
#        ...,
#        [184, 185, 186, ..., 180, 181, 181],
#        [184, 185, 186, ..., 179, 181, 180],
#        [184, 185, 187, ..., 180, 181, 180]], dtype=uint8)

# %%
#redimensionando a imagem

roi = cv2.resize(roi, (48, 48))
cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=L size=48x48 at 0x7F3243EE7358>

# %%
roi.dtype
# Out:
# dtype('uint8')

# %%
#transformando os valores para float

roi = roi.astype('float')
roi.dtype
# Out:
# dtype('float64')

# %%
roi
# Out:
# array([[ 33.,  29.,  38., ...,  16.,  22.,  25.],
#        [ 32.,  37.,  37., ...,  16.,  20.,  25.],
#        [ 32.,  36.,  31., ...,  17.,  21.,  25.],
#        ...,
#        [186., 189., 189., ..., 181., 181., 180.],
#        [185., 188., 189., ..., 180., 181., 180.],
#        [185., 188., 188., ..., 179., 180., 181.]])

# %%
#normalizando a imagem

roi = roi / 255

# %%
roi
# Out:
# array([[0.12941176, 0.11372549, 0.14901961, ..., 0.0627451 , 0.08627451,
#         0.09803922],
#        [0.1254902 , 0.14509804, 0.14509804, ..., 0.0627451 , 0.07843137,
#         0.09803922],
#        [0.1254902 , 0.14117647, 0.12156863, ..., 0.06666667, 0.08235294,
#         0.09803922],
#        ...,
#        [0.72941176, 0.74117647, 0.74117647, ..., 0.70980392, 0.70980392,
#         0.70588235],
#        [0.7254902 , 0.7372549 , 0.74117647, ..., 0.70588235, 0.70980392,
#         0.70588235],
#        [0.7254902 , 0.7372549 , 0.7372549 , ..., 0.70196078, 0.70588235,
#         0.70980392]])

# %%
roi = img_to_array(roi)

# %%
roi
# Out:
# array([[[0.12941177],
#         [0.11372549],
#         [0.14901961],
#         ...,
#         [0.0627451 ],
#         [0.08627451],
#         [0.09803922]],
#
#        [[0.1254902 ],
#         [0.14509805],
#         [0.14509805],
#         ...,
#         [0.0627451 ],
#         [0.07843138],
#         [0.09803922]],
#
#        [[0.1254902 ],
#         [0.14117648],
#         [0.12156863],
#         ...,
#         [0.06666667],
#         [0.08235294],
#         [0.09803922]],
#
#        ...,
#
#        [[0.7294118 ],
#         [0.7411765 ],
#         [0.7411765 ],
#         ...,
#         [0.70980394],
#         [0.70980394],
#         [0.7058824 ]],
#
#        [[0.7254902 ],
#         [0.7372549 ],
#         [0.7411765 ],
#         ...,
#         [0.7058824 ],
#         [0.70980394],
#         [0.7058824 ]],
#
#        [[0.7254902 ],
#         [0.7372549 ],
#         [0.7372549 ],
#         ...,
#         [0.7019608 ],
#         [0.7058824 ],
#         [0.70980394]]], dtype=float32)

# %%
roi.shape
# Out:
# (48, 48, 1)

# %%
#adicionando mais uma dimensão

roi = np.expand_dims(roi, axis = 0)

# %%
roi.shape
# Out:
# (1, 48, 48, 1)

# %% [markdown]
# ### Previsões

# %%
#fazendo a previsão das emoções

preds = classificador_emocoes.predict(roi)[0]

# %%
preds
# Out:
# array([1.6802111e-05, 5.7679777e-09, 1.1206568e-05, 9.9066460e-01,
#        1.8033772e-05, 1.8518280e-05, 9.2708217e-03], dtype=float32)

# %%
len(preds)
# Out:
# 7

# %%
#buscando o valor da maior probabilidade

emotion_probability = np.max(preds)
emotion_probability
# Out:
# 0.9906646

# %%
#buscando o índice do maior valor

preds.argmax()
# Out:
# 3

# %%
#relacionando o índice com a lista de emoções

label = expressoes[preds.argmax()]
label
# Out:
# 'Feliz'

# %% [markdown]
# ### Resultados

# %%
#colocando o texto referente a emoção detectada e o retângulo do roi

cv2.putText(original, label, (162, 40 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.65,
            (0, 0, 255), 2, cv2.LINE_AA)
cv2.rectangle(original, (162, 40), (162 + 128, 40 + 128), (0, 0, 255), 2)
cv2_imshow(original)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F3243A39518>

# %%
probabilidades = np.ones((250,300,3), dtype= 'uint8') * 255
probabilidades
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
probabilidades.shape
# Out:
# (250, 300, 3)

# %%
cv2_imshow(original)

#criando os retângulos de probabilidade para uma melhor visualização

if len(faces) == 1:
  for (i, (emotion, prob)) in enumerate(zip(expressoes, preds)):
    #print(i, emotion, prob)
    text = "{}: {:.2f}%".format(emotion, prob * 100)
    w = int(prob * 300)
    cv2.rectangle(probabilidades, (7, (i * 35) + 5), (w, (i * 35) + 35), (200, 250, 20), -1)
    cv2.putText(probabilidades, text, (10, (i * 35) + 23), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 0), 1, cv2.LINE_AA)
cv2_imshow(probabilidades)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F3243A392B0>
# <PIL.Image.Image image mode=RGB size=300x250 at 0x7F3243A39DD8>
